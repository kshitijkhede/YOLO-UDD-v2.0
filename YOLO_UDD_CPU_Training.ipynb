# %% [markdown]
# # 🌊 YOLO-UDD v2.0 - CPU Training (No GPU Required)
#
# **⚡ Optimized for CPU training with reduced epochs**
#
# Repository: https://github.com/kshitijkhede/YOLO-UDD-v2.0
#
# ---
#
# ## ⏱️ Expected Time:
# - COCO Conversion: ~5-10 minutes
# - Training (10 epochs): ~8-12 hours on CPU
#
# **Note:** For full training (50 epochs), please use GPU version!

# %% [markdown]
# ## Step 1: Clone Repository

# %%
# !git clone https://github.com/kshitijkhede/YOLO-UDD-v2.0.git
# %cd YOLO-UDD-v2.0
print("✅ Repository cloned!")

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# !pip install -q torch torchvision albumentations opencv-python-headless tqdm pyyaml tensorboard
print("✅ Dependencies installed!")

# %% [markdown]
# ## Step 3: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
print("✅ Google Drive mounted!")

# %% [markdown]
# ## Step 4: Check Dataset

# %%
import os

DATASET_ROOT = '/content/drive/MyDrive/TrashCan_dataset'
ORIGINAL_DATA = os.path.join(DATASET_ROOT, 'original_data')
IMAGES_DIR = os.path.join(ORIGINAL_DATA, 'images')
ANNOTATIONS_DIR = os.path.join(ORIGINAL_DATA, 'annotations')

print(f"Dataset: {ORIGINAL_DATA}")

if os.path.exists(IMAGES_DIR):
    img_count = len([f for f in os.listdir(IMAGES_DIR) if f.endswith('.jpg')])
    print(f"✅ {img_count} images")

if os.path.exists(ANNOTATIONS_DIR):
    ann_count = len([f for f in os.listdir(ANNOTATIONS_DIR) if f.endswith('.json')])
    print(f"✅ {ann_count} annotations")

# %% [markdown]
# ## Step 5: ⚡ FAST COCO Conversion

# %%
import json
import random
from tqdm import tqdm
import time

def fast_coco_convert(images_dir, annotations_dir, output_file, split='train', ratio=0.8):
    coco = {
        "images": [],
        "annotations": [],
        "categories": [
            {"id": 1, "name": "trash"},
            {"id": 2, "name": "animal"},
            {"id": 3, "name": "rov"}
        ]
    }
    
    images = sorted([f for f in os.listdir(images_dir) if f.endswith('.jpg')])
    random.seed(42)
    random.shuffle(images)
    
    split_idx = int(len(images) * ratio)
    selected = images[:split_idx] if split == 'train' else images[split_idx:]
    
    ann_id = 1
    
    for img_id, img_file in enumerate(tqdm(selected, desc=f"{split}"), 1):
        ann_file = os.path.join(annotations_dir, img_file + '.json')
        
        if not os.path.exists(ann_file):
            continue
        
        try:
            with open(ann_file, 'r') as f:
                data = json.load(f)
            
            size = data.get('size', {'width': 1920, 'height': 1080})
            
            coco["images"].append({
                "id": img_id,
                "file_name": img_file,
                "width": size.get('width', 1920),
                "height": size.get('height', 1080)
            })
            
            for obj in data.get('objects', []):
                cls = obj.get('classTitle', '').lower()
                cat_id = 1
                if 'animal' in cls or 'fish' in cls:
                    cat_id = 2
                elif 'rov' in cls:
                    cat_id = 3
                
                if 'points' in obj and 'exterior' in obj['points']:
                    pts = obj['points']['exterior']
                    xs = [p[0] for p in pts]
                    ys = [p[1] for p in pts]
                    x1, x2 = min(xs), max(xs)
                    y1, y2 = min(ys), max(ys)
                    w, h = x2 - x1, y2 - y1
                    
                    if w > 0 and h > 0:
                        coco["annotations"].append({
                            "id": ann_id,
                            "image_id": img_id,
                            "category_id": cat_id,
                            "bbox": [x1, y1, w, h],
                            "area": w * h,
                            "iscrowd": 0
                        })
                        ann_id += 1
        except:
            pass
    
    with open(output_file, 'w') as f:
        json.dump(coco, f)
    
    print(f"✅ {split}: {len(coco['images'])} images, {len(coco['annotations'])} boxes")

print("⚡ Converting to COCO format...\n")
start = time.time()

train_out = os.path.join(ORIGINAL_DATA, 'instances_train_trashcan.json')
val_out = os.path.join(ORIGINAL_DATA, 'instances_val_trashcan.json')

fast_coco_convert(IMAGES_DIR, ANNOTATIONS_DIR, train_out, 'train', 0.8)
fast_coco_convert(IMAGES_DIR, ANNOTATIONS_DIR, val_out, 'val', 0.8)

print(f"\n⏱️  Time: {(time.time()-start)/60:.1f} min")
print("✅ Done!")

# %% [markdown]
# ## Step 6: Check Hardware

# %%
import torch

print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print("   Training will be FAST (~4-6 hours)")
else:
    print("⚠️  No GPU detected - training on CPU")
    print("   Training will be SLOW (~8-12 hours for 10 epochs)")
    print("")
    print("   To enable GPU:")
    print("   1. Runtime → Change runtime type")
    print("   2. Hardware accelerator → T4 GPU")
    print("   3. Save and restart")

# %% [markdown]
# ## Step 7: Configure Training (CPU-Optimized)

# %%
# CPU-optimized settings
BATCH_SIZE = 4      # Smaller batch for CPU
EPOCHS = 10         # Reduced epochs for faster training
LR = 0.01
SAVE_DIR = 'runs/train'

print("=" * 60)
print("CPU-OPTIMIZED TRAINING CONFIGURATION")
print("=" * 60)
print(f"Batch Size: {BATCH_SIZE} (smaller for CPU)")
print(f"Epochs: {EPOCHS} (reduced from 50 for faster training)")
print(f"Learning Rate: {LR}")
print(f"Save Dir: {SAVE_DIR}")
print()
print("⏱️  Expected time: ~8-12 hours on CPU")
print("💡 For full training (50 epochs), use GPU version!")
print("=" * 60)

# %% [markdown]
# ## Step 8: 🚀 Train Model

# %%
# !python scripts/train.py \
  --data-dir "{ORIGINAL_DATA}" \
  --batch-size {BATCH_SIZE} \
  --epochs {EPOCHS} \
  --lr {LR} \
  --save-dir {SAVE_DIR}

# %% [markdown]
# ## Step 9: View Results

# %%
import glob

ckpt_dir = os.path.join(SAVE_DIR, 'checkpoints')
if os.path.exists(ckpt_dir):
    ckpts = glob.glob(os.path.join(ckpt_dir, '*.pt'))
    print(f"✅ Found {len(ckpts)} checkpoint(s):")
    for c in ckpts:
        size = os.path.getsize(c) / (1024*1024)
        print(f"   📦 {os.path.basename(c)} ({size:.1f} MB)")
else:
    print("⚠️  No checkpoints yet")
    print("   Training may still be in progress")

# %% [markdown]
# ## Step 10: Download Model

# %%
from google.colab import files

best_model = os.path.join(SAVE_DIR, 'checkpoints', 'best_model.pt')
if os.path.exists(best_model):
    files.download(best_model)
    print("✅ Download started!")
else:
    print("❌ Model not found")
    print("   Training may not have completed")
